# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from src.models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0],
    "regressor__reg__l1_ratio": [0.1, 0.25, 0.5, 0.75, 0.9],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=ElasticNet(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.087e+01, tolerance: 1.448e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.288e+01, tolerance: 1.438e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.819e+01, tolerance: 1.430e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.430e+01, tolerance: 1.423e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.114e+01, tolerance: 1.466e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.001e+01, tolerance: 1.422e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.050e+02, tolerance: 1.427e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.398e+02, tolerance: 1.778e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0],
#                          'regressor__reg__l1_ratio': [0.1, 0.25, 0.5, 0.75,
#                                                       0.9]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 0.01,
#  'regressor__reg__l1_ratio': 0.1}

# %%
grid_search.best_score_
# Out:
# np.float64(-51316.3915567185)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# one_hot__ocean_proximity_INLAND                       -0.601080
# robust_scaler_poly__longitude                         -0.380050
# robust_scaler_poly__population_per_household          -0.342507
# robust_scaler_poly__latitude                          -0.213590
# robust_scaler_poly__latitude^2                        -0.193939
# ...                                                         ...
# ordinal_encoder__median_income_cat                     0.092227
# robust_scaler_poly__housing_median_age longitude^2     0.108864
# robust_scaler_poly__bedrooms_per_room                  0.129808
# robust_scaler_poly__housing_median_age median_i...     0.180508
# robust_scaler_poly__median_income                      0.719644
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
#                                                     coeficiente
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household to...          0.0
# robust_scaler_poly__population_per_household ro...         -0.0
# robust_scaler_poly__total_rooms^3                           0.0
# ...                                                         ...
# robust_scaler_poly__latitude rooms_per_househol...         -0.0
# robust_scaler_poly__longitude rooms_per_househo...          0.0
# robust_scaler_poly__longitude total_bedrooms^2             -0.0
# robust_scaler_poly__population rooms_per_househ...         -0.0
# robust_scaler_poly__population rooms_per_househ...         -0.0
#
# [210 rows x 1 columns]

# %%
coefs[coefs["coeficiente"].between(-0.1, 0.1) & (coefs["coeficiente"] != 0)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__bedrooms_per_room^2 median_...    -0.082741
# robust_scaler_poly__bedrooms_per_room^2 latitude      -0.074966
# robust_scaler_poly__housing_median_age latitude       -0.068373
# robust_scaler_poly__median_income^2                   -0.067539
# robust_scaler_poly__median_income population_pe...    -0.060084
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.075489
# robust_scaler_poly__housing_median_age populati...     0.085076
# robust_scaler_poly__housing_median_age                 0.087659
# robust_scaler_poly__median_income total_bedrooms       0.091776
# ordinal_encoder__median_income_cat                     0.092227
#
# [142 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.1, 0.1)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "ElasticNet_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.161e+01, tolerance: 1.436e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.642e+01, tolerance: 1.423e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.022e+01, tolerance: 1.436e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.433e+02, tolerance: 1.407e+00
#   model = cd_fast.enet_coordinate_descent(
# /home/evlos/myprojects/Ciencias_Dados_Impressionador/14.Regressao_Modelos_Lineares/.venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.239e+01, tolerance: 1.423e+00
#   model = cd_fast.enet_coordinate_descent(
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.002275   0.002253 -0.000081
# 1            DummyRegressor  0.001835    0.00167 -0.000146
# 2            DummyRegressor  0.001216   0.001583 -0.001737
# 3            DummyRegressor  0.001868   0.002009 -0.000101
# 4            DummyRegressor   0.00122   0.001553 -0.000114
# 5          LinearRegression  0.028507   0.005075  0.682162
# 6          LinearRegression  0.013751    0.00517   0.66999
# 7          LinearRegression  0.013272   0.004981  0.649247
# 8          LinearRegression  0.013362    0.00582  0.669873
# 9          LinearRegression  0.014185   0.004495  0.669023
# 10  LinearRegression_target  0.017407   0.004974  0.691567
# 11  LinearRegression_target  0.016781   0.004775  0.678579
# 12  LinearRegression_target  0.016197   0.005009  0.654215
# 13  LinearRegression_target   0.01788    0.00565  0.683858
# 14  LinearRegression_target  0.017786   0.004822  0.682597
# 15   ElasticNet_grid_search    4.4178   0.033158  0.733881
# 16   ElasticNet_grid_search  3.815593   0.013658  0.713657
# 17   ElasticNet_grid_search  3.680629   0.018617  0.688025
# 18   ElasticNet_grid_search  3.825818   0.012783  0.718248
# 19   ElasticNet_grid_search  3.420125   0.015174  0.716144
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.004527
# 1                 -75787.787194                    -95217.629397     0.003505
# 2                 -76753.598961                    -96253.253947     0.002798
# 3                 -76837.804811                    -95983.885799     0.003877
# 4                 -76617.245449                    -96182.764729     0.002772
# 5                 -39855.690996                    -54254.958188     0.033582
# 6                 -40272.565467                    -54695.230283     0.018921
# 7                  -42178.05929                    -56955.988706     0.018253
# 8                 -40806.492497                    -55146.318803     0.019181
# 9                 -40788.496497                     -55331.35106      0.01868
# 10                -37804.958313                    -53446.197978     0.022381
# 11                -38269.198512                    -53978.728616     0.021556
# 12                -40280.519598                    -56551.132657     0.021206
# 13                -38592.851583                    -53965.607549     0.023531
# 14                -38410.574341                    -54184.817593     0.022608
# 15                -34886.601455                    -49644.937167     4.450958
# 16                -35625.275764                    -50948.193208     3.829251
# 17                -37603.615901                    -53715.317048     3.699246
# 18                -35939.549638                    -50946.009536     3.838601
# 19                -35976.224629                    -51241.448377     3.435299

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.001683   0.001813 -0.000436
# ElasticNet_grid_search   3.831993   0.018678  0.713991
# LinearRegression         0.016615   0.005108  0.668059
# LinearRegression_target   0.01721   0.005046  0.678164
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# ElasticNet_grid_search                 -36006.253477
# LinearRegression                        -40780.26095
# LinearRegression_target                -38671.620469
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.003496
# ElasticNet_grid_search                     -51299.181067     3.850671
# LinearRegression                           -55276.769408     0.021723
# LinearRegression_target                    -54425.296879     0.022256

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.001683   0.001813 -0.000436
# LinearRegression         0.016615   0.005108  0.668059
# LinearRegression_target   0.01721   0.005046  0.678164
# ElasticNet_grid_search   3.831993   0.018678  0.713991
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                -38671.620469
# ElasticNet_grid_search                 -36006.253477
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.003496
# LinearRegression                           -55276.769408     0.021723
# LinearRegression_target                    -54425.296879     0.022256
# ElasticNet_grid_search                     -51299.181067     3.850671

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)
